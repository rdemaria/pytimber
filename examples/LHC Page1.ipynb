# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.dates import epoch2num
import time

# %%
import pytimber
db=pytimber.LoggingDB()

# %%
now=time.time()
ib1="LHC.BCTDC.A6R4.B1:BEAM_INTENSITY"
ib2="LHC.BCTDC.A6R4.B2:BEAM_INTENSITY"
nrg="LHC.BOFSU:OFSU_ENERGY"
data=db.get([ib1,ib2,nrg],now-3600*24,now)

# %%
plt.clf()
tt,vv=data[ib1]
plt.plot_date(epoch2num(tt),vv,'-b',label='Beam1')
tt,vv=data[ib2]
plt.plot_date(epoch2num(tt),vv,'-r',label='Beam2')
plt.ylabel('Protons')
plt.twinx()
tt,vv=data[nrg]
plt.plot_date(epoch2num(tt),vv,'-g',label='Energy')
plt.ylabel('Erergy [GeV]')
plt.title(time.asctime(time.localtime(now)))
# Out:
# <img src="data:image/png;base64,...">

# %%
db.search("LHC.BOFSU:%ENERGY%")
# Out:
# [u'LHC.BOFSU:ENERGY_FB_STATE',
#  u'LHC.BOFSU:OFC_ENERGY',
#  u'LHC.BOFSU:OFSU_ENERGY']

# %%
db.search("LHC.STATS%ENERGY%")
# Out:
# [u'LHC.STATS:ENERGY',
#  u'LHC.STATS:SPS_H_ROT_IN:ENERGY',
#  u'LHC.STATS:SPS_V_ROT_IN:ENERGY',
#  u'LHC.STATS:STORED_ENERGY_B1_SSB',
#  u'LHC.STATS:STORED_ENERGY_B2_SSB']

# %%
db.search("%B1%BEAM_INTENSITY%")
# Out:
# [u'LHC.BCTDC.A6R4.B1:BEAM_INTENSITY',
#  u'LHC.BCTDC.A6R4.B1:BEAM_INTENSITY_ADC24BIT',
#  u'LHC.BCTDC.B6R4.B1:BEAM_INTENSITY',
#  u'LHC.BCTDC.B6R4.B1:BEAM_INTENSITY_ADC24BIT',
#  u'LHC.BCTFR.A6R4.B1:BEAM_INTENSITY',
#  u'LHC.BCTFR.A6R4.B1:BEAM_INTENSITY_LOBW',
#  u'LHC.BCTFR.B6R4.B1.DEV:BEAM_INTENSITY_HBW',
#  u'LHC.BCTFR.B6R4.B1.DEV:BEAM_INTENSITY_LBW',
#  u'LHC.BCTFR.B6R4.B1:BEAM_INTENSITY',
#  u'LHC.BCTFR.B6R4.B1:BEAM_INTENSITY_LOBW',
#  u'LHC.BWCM.B1:BEAM_INTENSITY']
